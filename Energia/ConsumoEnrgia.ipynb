# %%
import pandas as pd

datos=pd.read_csv('Fuentes_Consumo_Energia.csv')
datos
# Out:
#       Entity      Code  Year  Coal_Consumption_EJ  Gas_Consumption_EJ  \
# 0     Africa       NaN  1965             1.164586            0.034358
# 1     Africa       NaN  1966             1.163240            0.038412
# 2     Africa       NaN  1967             1.189050            0.037964
# 3     Africa       NaN  1968             1.236646            0.038480
# 4     Africa       NaN  1969             1.247915            0.044971
# ...      ...       ...   ...                  ...                 ...
# 5185   World  OWID_WRL  2015           157.838896          125.208335
# 5186   World  OWID_WRL  2016           155.504177          128.124027
# 5187   World  OWID_WRL  2017           156.094106          131.708206
# 5188   World  OWID_WRL  2018           158.793935          138.659832
# 5189   World  OWID_WRL  2019           157.857047          141.452770
#
#       Geo_Biomass_Other_TWh  Hydro_Generation_TWh  Nuclear_Generation_TWh  \
# ...

# %%
datos.dtypes
# Out:
# Entity                     object
# Code                       object
# Year                        int64
# Coal_Consumption_EJ       float64
# Gas_Consumption_EJ        float64
# Geo_Biomass_Other_TWh     float64
# Hydro_Generation_TWh      float64
# Nuclear_Generation_TWh    float64
# Solar_Generation_TWh      float64
# Wind_Generation_TWh       float64
# Oil_Consumption_EJ        float64
# dtype: object

# %%
datos.iloc[164]
# Out:
# Entity                    Argentina
# Code                            ARG
# Year                           2019
# Coal_Consumption_EJ        0.022852
# Gas_Consumption_EJ         1.709661
# Geo_Biomass_Other_TWh      2.397314
# Hydro_Generation_TWh      37.066787
# Nuclear_Generation_TWh     8.441898
# Solar_Generation_TWh       0.799698
# Wind_Generation_TWh        4.995966
# Oil_Consumption_EJ          1.18558
# Name: 164, dtype: object

# %%
resultado=datos[datos['Year']==2019]
paises=['Argentina','Brazil','Chile','Colombia','Ecuador','Mexico','Peru']
ind=[]
for i,j in enumerate(resultado['Entity']):
    if j in paises:
        ind.append(i)
ind

resultado=resultado.iloc[ind]
resultado
# Out:
#          Entity Code  Year  Coal_Consumption_EJ  Gas_Consumption_EJ  \
# 164   Argentina  ARG  2019             0.022852            1.709661
# 564      Brazil  BRA  2019             0.656077            1.289142
# 839       Chile  CHL  2019             0.284529            0.233328
# 949    Colombia  COL  2019             0.257706            0.484072
# 1254    Ecuador  ECU  2019             0.000000            0.022754
# 2634     Mexico  MEX  2019             0.507516            3.264027
# 3569       Peru  PER  2019             0.021773            0.298798
#
#       Geo_Biomass_Other_TWh  Hydro_Generation_TWh  Nuclear_Generation_TWh  \
# 164                2.397314             37.066787                8.441898
# 564               56.254366            399.297116               16.164832
# 839                9.992204             20.852753                0.000000
# 949                2.047531             51.542435                0.000000
# ...

# %%
maximo=resultado['Wind_Generation_TWh'].max()
pais=resultado[resultado['Wind_Generation_TWh']==maximo]
final=pd.DataFrame(pais.groupby(['Entity']))
#final=pd.DataFrame(pais.groupby(['Entity','Wind_Generation_TWh']))
p=str(final[0].to_numpy())[2:-2]
p
# Out:
# 'Brazil'
